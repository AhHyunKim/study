# %% [markdown]
# https://dgkim5360.tistory.com/entry/python-requests 참조

# %%
from urllib.request import urlopen 
from urllib.parse import urlencode, unquote, quote_plus 
import urllib 
import requests 
import json 
import pandas as pd

from datetime import datetime

# %%
url = ' http://fedoraapidev.haezoom.com/api/monitor/charts/'

# %%
headers = {'authorization': 'Basic MDEwNTE3MDc4NTU6aWRuc3RvcnkxMzI='}
data = {'plant_id':110,'query_type':'daily','query_when':'2021-05-10'}

# %%
res = requests.post(url, headers=headers,data=data)

# %%
res.request
# Out:
# <PreparedRequest [POST]>

# %%
res.status_code
# Out:
# 200

# %%
res.raise_for_status()

# %%
json_data = res.json()

# %%
json_data
# Out:
# {'status': 'success',
#  'message': '조회 성공',
#  'code': 200,
#  'result': {'plant_id': 110,
#   'time_list': ['05:00',
#    '06:00',
#    '07:00',
#    '08:00',
#    '09:00',
#    '10:00',
#    '11:00',
#    '12:00',
#    '13:00',
#    '14:00',
#    '15:00',
#    '16:00',
#    '17:00',
#    '18:00',
#    '19:00',
#    '20:00',
#    '21:00',
#    '22:00'],
#   'forecast': [],
#   'vst_forecast': [],
#   'combined_forecast': [],
#   'gen_amounts': [0.0,
#    0.0,
#    20.2,
#    65.5,
#    131.8,
#    147.6,
#    187.9,
#    272.2,
#    284.4,
#    356.4,
#    532.1,
#    281.5,
#    157.7,
#    115.2,
#    61.9,
#    2.9,
#    0.0,
#    0.0],
#   'profit_amounts': [],
#   'gen_times': [],
#   'total_gen_amounts': 2617.3,
#   'total_combined_forecast': 0,
#   'total_gen_times': 2.7,
#   'day_list': ['05:00',
#    '06:00',
#    '07:00',
#    '08:00',
#    '09:00',
#    '10:00',
#    '11:00',
#    '12:00',
#    '13:00',
#    '14:00',
#    '15:00',
#    '16:00',
#    '17:00',
#    '18:00',
#    '19:00',
#    '20:00',
#    '21:00',
#    '22:00'],
#   'smp_profit': [],
#   'rec_profit': [],
#   'day_list_origin': [],
#   'weather': {'cur_weather': '흐림', 'cur_temp': 13, 'icon': '04d'},
#   'weather_list': [],
#   'total_profit_amounts': 0}}

# %%
start_date = '20210510'

url = ' http://fedoraapidev.haezoom.com/api/monitor/charts/'
headers = {'authorization': 'Basic MDEwNTE3MDc4NTU6aWRuc3RvcnkxMzI='}
data_info = {'plant_id':110,'query_type':'daily','query_when':start_date}
res = requests.post(url, headers=headers,data=data_info)
res.json()
# Out:
# {'status': 'error', 'code': 400, 'message': '차트 조회 실패'}

# %%
json_data.keys()
# Out:
# dict_keys(['status', 'message', 'code', 'result'])

# %%
json_data['result'].keys()
# Out:
# dict_keys(['plant_id', 'time_list', 'forecast', 'vst_forecast', 'combined_forecast', 'gen_amounts', 'profit_amounts', 'gen_times', 'total_gen_amounts', 'total_combined_forecast', 'total_gen_times', 'day_list', 'smp_profit', 'rec_profit', 'day_list_origin', 'weather', 'weather_list', 'total_profit_amounts'])

# %%
json_data['result']['gen_amounts']
# Out:
# [0.0,
#  0.0,
#  20.2,
#  65.5,
#  131.8,
#  147.6,
#  187.9,
#  272.2,
#  284.4,
#  356.4,
#  532.1,
#  281.5,
#  157.7,
#  115.2,
#  61.9,
#  2.9,
#  0.0,
#  0.0]

# %% [markdown]
# ### Get 요청할 때 parameter 요청법
# * query string method라고도 부름

# %%
#url = 'http://data.kma.go.kr/apiData/getData'
url = 'http://apis.data.go.kr/1360000/AsosHourlyInfoService'

# %%
url_open = url+'/getWthrDataList'
params = '?' + urlencode({ 
                          quote_plus("serviceKey"): "4NfC7ZkaapuJ5q67Kn4bSww5qqNx5Gh0%2F83Tf0Uk3VRd10DfXOJVK7DY0e5r1ikv94iIARxpD7W4UM0gr88K1A%3D%3D",
                          quote_plus("dataType"): "json", 
                          quote_plus("dataCd"): "ASOS", 
                          quote_plus("dateCd"): "HR", 
                          
                          quote_plus("startDt"): "20200212", 
                          quote_plus("startHh"): "00", 
                          quote_plus("endDt"): "20200212", 
                          quote_plus("endHh") : "23", 
                          quote_plus("stnIds"): "108", 
                          
                          #quote_plus("schListCnt"): "500",
                          #quote_plus("pageIndex"): "1",
                          #quote_plus("apiKey"): "4NfC7ZkaapuJ5q67Kn4bSww5qqNx5Gh0%2F83Tf0Uk3VRd10DfXOJVK7DY0e5r1ikv94iIARxpD7W4UM0gr88K1A%3D%3D" })
                        #  quote_plus("apiKey"): "사용자 키 입력" 
             })

# %%
req = urllib.request.Request(url_open + unquote(params))

# %%
response_body = urlopen(req, timeout=60).read()

# %%
data = json.loads(response_body)

# %%
data.keys()
# Out:
# dict_keys(['response'])

# %%
 data['response'].keys()
# Out:
# dict_keys(['header', 'body'])

# %%
 data['response']['header'].keys()
# Out:
# dict_keys(['resultCode', 'resultMsg'])

# %%
 data['response']['body'].keys()
# Out:
# dict_keys(['dataType', 'items', 'pageNo', 'numOfRows', 'totalCount'])

# %%
pd.DataFrame(data['response']['body']['items']['item'])
# Out:
#   clfmAbbrCd dc10LmcsCa dc10Tca dmstMtphNo dsnw gndSttCd  hm hmQcflg hr3Fhsc  \
# 0         Ci          0       8                           35
# 1                    10      10                           32
# 2                    10      10                           35
# 3       ScAc          6       9                           37
# 4       ScAs          6      10       4001                45
# 5       ScAs          6      10       4001                52
# 6       ScAs          7      10       4001                47
# 7       StNs          8      10       4001                48
# 8       StNs          8      10         01                47
# 9       StNs          8      10         01                46
#
#    icsr  ... taQcflg    td                tm   ts tsQcflg    vs   wd wdQcflg  \
# 0        ...          -6.8  2020-02-12 00:00  3.5          1075   20
# 1        ...          -8.1  2020-02-12 01:00  3.5          1139   70
# 2        ...          -7.1  2020-02-12 02:00  3.5          1071   70
# 3        ...          -6.6  2020-02-12 03:00  3.6          1084   50
# 4        ...          -4.2  2020-02-12 04:00  3.8           926   50
# 5        ...          -2.4  2020-02-12 05:00  3.9          1035   70
# 6        ...          -3.7  2020-02-12 06:00  3.9           992  110
# 7        ...          -3.5  2020-02-12 07:00  3.9          1081   70
# 8   0.0  ...          -3.7  2020-02-12 08:00  4.1          1007   70
# 9  0.07  ...          -3.8  2020-02-12 09:00  4.6          1166   70
#
#     ws wsQcflg
# 0  0.5
# 1  0.9
# 2  1.2
# 3  1.3
# 4  1.0
# 5  1.1
# 6  2.1
# 7  1.7
# 8  2.5
# 9  3.9
#
# [10 rows x 38 columns]

# %%
print(json.dumps(data['response'],indent=4, sort_keys=True)[] )
# Out:
# {
#     "body": {
#         "dataType": "JSON",
#         "items": {
#             "item": [
#                 {
#                     "clfmAbbrCd": "Ci",
#                     "dc10LmcsCa": "0",
#                     "dc10Tca": "8",
#                     "dmstMtphNo": "",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "35",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "",
#                     "m005Te": "4.1",
#                     "m01Te": "4.4",
#                     "m02Te": "4.1",
#                     "m03Te": "4.2",
#                     "pa": "1014.1",
#                     "paQcflg": "",
#                     "ps": "1024.6",
#                     "psQcflg": "",
#                     "pv": "3.7",
#                     "rn": "",
#                     "rnQcflg": "",
#                     "rnum": "1",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "7.7",
#                     "taQcflg": "",
#                     "td": "-6.8",
#                     "tm": "2020-02-12 00:00",
#                     "ts": "3.5",
#                     "tsQcflg": "",
#                     "vs": "1075",
#                     "wd": "20",
#                     "wdQcflg": "",
#                     "ws": "0.5",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "",
#                     "dc10LmcsCa": "10",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "32",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "30",
#                     "m005Te": "4.1",
#                     "m01Te": "4.2",
#                     "m02Te": "4.0",
#                     "m03Te": "4.2",
#                     "pa": "1013.7",
#                     "paQcflg": "",
#                     "ps": "1024.3",
#                     "psQcflg": "",
#                     "pv": "3.3",
#                     "rn": "",
#                     "rnQcflg": "",
#                     "rnum": "2",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "7.5",
#                     "taQcflg": "",
#                     "td": "-8.1",
#                     "tm": "2020-02-12 01:00",
#                     "ts": "3.5",
#                     "tsQcflg": "",
#                     "vs": "1139",
#                     "wd": "70",
#                     "wdQcflg": "",
#                     "ws": "0.9",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "",
#                     "dc10LmcsCa": "10",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "35",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "28",
#                     "m005Te": "4.1",
#                     "m01Te": "4.2",
#                     "m02Te": "4.0",
#                     "m03Te": "4.1",
#                     "pa": "1013.3",
#                     "paQcflg": "",
#                     "ps": "1023.9",
#                     "psQcflg": "",
#                     "pv": "3.6",
#                     "rn": "",
#                     "rnQcflg": "",
#                     "rnum": "3",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "7.3",
#                     "taQcflg": "",
#                     "td": "-7.1",
#                     "tm": "2020-02-12 02:00",
#                     "ts": "3.5",
#                     "tsQcflg": "",
#                     "vs": "1071",
#                     "wd": "70",
#                     "wdQcflg": "",
#                     "ws": "1.2",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "ScAc",
#                     "dc10LmcsCa": "6",
#                     "dc10Tca": "9",
#                     "dmstMtphNo": "",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "37",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "10",
#                     "m005Te": "4.0",
#                     "m01Te": "4.1",
#                     "m02Te": "4.0",
#                     "m03Te": "4.1",
#                     "pa": "1012.4",
#                     "paQcflg": "",
#                     "ps": "1023.0",
#                     "psQcflg": "",
#                     "pv": "3.7",
#                     "rn": "",
#                     "rnQcflg": "",
#                     "rnum": "4",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "7.1",
#                     "taQcflg": "",
#                     "td": "-6.6",
#                     "tm": "2020-02-12 03:00",
#                     "ts": "3.6",
#                     "tsQcflg": "",
#                     "vs": "1084",
#                     "wd": "50",
#                     "wdQcflg": "",
#                     "ws": "1.3",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "ScAs",
#                     "dc10LmcsCa": "6",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "4001",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "45",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "10",
#                     "m005Te": "4.0",
#                     "m01Te": "4.0",
#                     "m02Te": "3.9",
#                     "m03Te": "4.2",
#                     "pa": "1011.5",
#                     "paQcflg": "",
#                     "ps": "1022.1",
#                     "psQcflg": "",
#                     "pv": "4.5",
#                     "rn": "",
#                     "rnQcflg": "9",
#                     "rnum": "5",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "6.9",
#                     "taQcflg": "",
#                     "td": "-4.2",
#                     "tm": "2020-02-12 04:00",
#                     "ts": "3.8",
#                     "tsQcflg": "",
#                     "vs": "926",
#                     "wd": "50",
#                     "wdQcflg": "",
#                     "ws": "1.0",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "ScAs",
#                     "dc10LmcsCa": "6",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "4001",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "52",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "12",
#                     "m005Te": "4.0",
#                     "m01Te": "4.0",
#                     "m02Te": "3.8",
#                     "m03Te": "4.1",
#                     "pa": "1010.7",
#                     "paQcflg": "",
#                     "ps": "1021.3",
#                     "psQcflg": "",
#                     "pv": "5.1",
#                     "rn": "",
#                     "rnQcflg": "9",
#                     "rnum": "6",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "6.7",
#                     "taQcflg": "",
#                     "td": "-2.4",
#                     "tm": "2020-02-12 05:00",
#                     "ts": "3.9",
#                     "tsQcflg": "",
#                     "vs": "1035",
#                     "wd": "70",
#                     "wdQcflg": "",
#                     "ws": "1.1",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "ScAs",
#                     "dc10LmcsCa": "7",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "4001",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "47",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "10",
#                     "m005Te": "4.1",
#                     "m01Te": "3.9",
#                     "m02Te": "3.8",
#                     "m03Te": "4.1",
#                     "pa": "1010.2",
#                     "paQcflg": "",
#                     "ps": "1020.8",
#                     "psQcflg": "",
#                     "pv": "4.6",
#                     "rn": "0.1",
#                     "rnQcflg": "",
#                     "rnum": "7",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "6.8",
#                     "taQcflg": "",
#                     "td": "-3.7",
#                     "tm": "2020-02-12 06:00",
#                     "ts": "3.9",
#                     "tsQcflg": "",
#                     "vs": "992",
#                     "wd": "110",
#                     "wdQcflg": "",
#                     "ws": "2.1",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "StNs",
#                     "dc10LmcsCa": "8",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "4001",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "48",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "",
#                     "lcsCh": "7",
#                     "m005Te": "4.1",
#                     "m01Te": "4.0",
#                     "m02Te": "3.8",
#                     "m03Te": "4.1",
#                     "pa": "1009.6",
#                     "paQcflg": "",
#                     "ps": "1020.1",
#                     "psQcflg": "",
#                     "pv": "4.7",
#                     "rn": "",
#                     "rnQcflg": "9",
#                     "rnum": "8",
#                     "ss": "",
#                     "ssQcflg": "9",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "6.7",
#                     "taQcflg": "",
#                     "td": "-3.5",
#                     "tm": "2020-02-12 07:00",
#                     "ts": "3.9",
#                     "tsQcflg": "",
#                     "vs": "1081",
#                     "wd": "70",
#                     "wdQcflg": "",
#                     "ws": "1.7",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "StNs",
#                     "dc10LmcsCa": "8",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "01",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "47",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "0.0",
#                     "lcsCh": "8",
#                     "m005Te": "4.2",
#                     "m01Te": "4.0",
#                     "m02Te": "3.8",
#                     "m03Te": "4.1",
#                     "pa": "1009.3",
#                     "paQcflg": "",
#                     "ps": "1019.8",
#                     "psQcflg": "",
#                     "pv": "4.6",
#                     "rn": "",
#                     "rnQcflg": "9",
#                     "rnum": "9",
#                     "ss": "0.0",
#                     "ssQcflg": "",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "6.8",
#                     "taQcflg": "",
#                     "td": "-3.7",
#                     "tm": "2020-02-12 08:00",
#                     "ts": "4.1",
#                     "tsQcflg": "",
#                     "vs": "1007",
#                     "wd": "70",
#                     "wdQcflg": "",
#                     "ws": "2.5",
#                     "wsQcflg": ""
#                 },
#                 {
#                     "clfmAbbrCd": "StNs",
#                     "dc10LmcsCa": "8",
#                     "dc10Tca": "10",
#                     "dmstMtphNo": "01",
#                     "dsnw": "",
#                     "gndSttCd": "",
#                     "hm": "46",
#                     "hmQcflg": "",
#                     "hr3Fhsc": "",
#                     "icsr": "0.07",
#                     "lcsCh": "9",
#                     "m005Te": "4.2",
#                     "m01Te": "4.0",
#                     "m02Te": "3.8",
#                     "m03Te": "4.1",
#                     "pa": "1009.0",
#                     "paQcflg": "",
#                     "ps": "1019.5",
#                     "psQcflg": "",
#                     "pv": "4.6",
#                     "rn": "0.0",
#                     "rnQcflg": "",
#                     "rnum": "10",
#                     "ss": "0.0",
#                     "ssQcflg": "",
#                     "stnId": "108",
#                     "stnNm": "\uc11c\uc6b8",
#                     "ta": "7.0",
#                     "taQcflg": "",
#                     "td": "-3.8",
#                     "tm": "2020-02-12 09:00",
#                     "ts": "4.6",
#                     "tsQcflg": "",
#                     "vs": "1166",
#                     "wd": "70",
#                     "wdQcflg": "",
#                     "ws": "3.9",
#                     "wsQcflg": ""
#                 }
#             ]
#         },
#         "numOfRows": 10,
#         "pageNo": 1,
#         "totalCount": 24
#     },
#     "header": {
#         "resultCode": "00",
#         "resultMsg": "NORMAL_SERVICE"
#     }
# }
